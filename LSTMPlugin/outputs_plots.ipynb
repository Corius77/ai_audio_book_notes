# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import read

# %%
def make_plot(filename, x1, x2):
  samplerate, data = read(filename)
  channal = data[:, 0] if data.ndim > 1 else data
  length = data.shape[0] / samplerate
  time = np.linspace(0., length, data.shape[0])
  plt.plot(time, data, label="Left channel")
  plt.xlim(x1 / samplerate, x2 / samplerate) 
  plt.ylim(min(data), max(data))
  plt.legend()
  plt.show()
  return len(data)

# %%
make_plot('sine_400_16bit.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_no_state.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_with_state.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_no_state1.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_with_state1.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_no_state2.wav', 0, 1024)
# Out:
# 44100

# %%
make_plot('proc_with_state2.wav', 0, 1024)
# Out:
# 44100
